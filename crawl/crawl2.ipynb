# %%
# title, author, price, publisher
import requests

url = "https://openapi.naver.com/v1/search/book.json"
headers = {
    "X-Naver-Client-Id": "YLPcyRzSCyVPhrp4HzrV",
    "X-Naver-Client-Secret": "We7CJm5vgN",
}

start = 1
book_csv_list = []
no = 1

for idx in range(10):
    start_num = start + (idx * 100)

    params = {"query": "주식", "display": 100, "start": start_num}

    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(contents)



    for books in contents["items"]:
        # print(f"{books["title"]}, {books['author']}, {books['discount']}, {books['publisher']}")
        book_csv_list.append([no, books["title"], books['author'], books['discount'], books['publisher']])
        no += 1

print(book_csv_list)
# Out:
# [[1, '나는 월급쟁이 배당 부자가 되었다 (배당투자로 월 300만 원 제2의 월급 만드는 시스템)', '환상감자(이은호)', '19800', '길벗'], [2, '완벽한 종목 추천 (종목 발굴부터 피칭까지 월가의 실전 투자 수업)', '폴 손킨^폴 존슨', '22500', '에프엔미디어'], [3, '손실은 짧게 수익은 길게 (자기만의 손익비를 찾아라!)', '깡토', '22500', '이레미디어'], [4, '허영만의 주식 타짜 ― 슈퍼개미 이세무사', '허영만', '15120', '가디언'], [5, '켄 피셔 불변의 차트 90 (극심한 변동성에도 살아남는 대가의 투자법)', '켄 피셔', '27000', '한국경제신문'], [6, '실패를 성공으로 바꾸는 주식투자의 기술 (초보 투자자를 위한 부자아빠의 핵심 트레이닝)', '정재호', '18900', '프런트페이지'], [7, '성공적인 개인 투자를 위한 ETF 안내서', '안해성', '17820', '지음미디어'], [8, '평생 투자자 (일본 주식시장의 판을 흔들어 깨운 담대한 도전들)', '무라카미 요시아키', '19800', '에프엔미디어'], [9, 'AI 텐베거 투자 (뉴사이클에 진입한 AI 혁명 산업, 10배 종목 발굴을 위한 전략서)', '이형수', '35010', '지베르니'], [10, '해외선물 처음공부 (단돈 100만 원으로 달러, 금, 오일, 나스닥선물을 시작할 수 있는)', '김직선', '22500', '이레미디어'], [11, '미국 주식이 답이다 2026 (차근차근 부자 되는 미국 주식투자 입문서)', '장우석^이항영', '23400', '페이지2북스'], [12, '돈, 뜨겁게 사랑하고 차갑게 다루어라', '앙드레 코스톨라니', '10800', '미래의창'], [13, '단 3개의 미국 ETF로 은퇴하라 (원하는 삶을 앞당기는 돈 자동 사냥 시스템)', '김지훈(포메뽀꼬)', '17820', '리더스북'], [14, '월가의 영웅 (주식투자에서 상식으로 성공하는 법)'
# ...

# %%
# csv 저장
import csv

with open("./data/books.csv", "w", encoding="utf-8", newline="") as f:
    wt = csv.writer(f)
    wt.writerows(book_csv_list)

# %%
# 몽고DB 저장
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://test:BTW4NOxKROZyov2K@cluster0.owgglvt.mongodb.net/"
)

url = "https://openapi.naver.com/v1/search/book.json"
headers = {
    "X-Naver-Client-Id": "YLPcyRzSCyVPhrp4HzrV",
    "X-Naver-Client-Secret": "We7CJm5vgN",
}
start = 1

books_list = []

for idx in range(10):
    start_num = start + (idx * 100)

    params = {"query": "주식", "display": 100, "start": start_num}

    res = requests.get(url, params=params, headers=headers)
    contents = res.json()

    for book in contents["items"]:
        books = {
            "title": book["title"],
            "author": book["author"],
            "price": book["discount"],
            "publisher": book["publisher"],
        }
        books_list.append(books)

# %%
# 몽고DB 저장
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://test:BTW4NOxKROZyov2K@cluster0.owgglvt.mongodb.net/"
)

# 컬렉션 가져오기
db = client["test"]
books = db.books

books.insert_many(books_list)
# Out:
# InsertManyResult([ObjectId('684ba1cee912bcea5de53211'), ObjectId('684ba1cee912bcea5de53212'), ObjectId('684ba1cee912bcea5de53213'), ObjectId('684ba1cee912bcea5de53214'), ObjectId('684ba1cee912bcea5de53215'), ObjectId('684ba1cee912bcea5de53216'), ObjectId('684ba1cee912bcea5de53217'), ObjectId('684ba1cee912bcea5de53218'), ObjectId('684ba1cee912bcea5de53219'), ObjectId('684ba1cee912bcea5de5321a'), ObjectId('684ba1cee912bcea5de5321b'), ObjectId('684ba1cee912bcea5de5321c'), ObjectId('684ba1cee912bcea5de5321d'), ObjectId('684ba1cee912bcea5de5321e'), ObjectId('684ba1cee912bcea5de5321f'), ObjectId('684ba1cee912bcea5de53220'), ObjectId('684ba1cee912bcea5de53221'), ObjectId('684ba1cee912bcea5de53222'), ObjectId('684ba1cee912bcea5de53223'), ObjectId('684ba1cee912bcea5de53224'), ObjectId('684ba1cee912bcea5de53225'), ObjectId('684ba1cee912bcea5de53226'), ObjectId('684ba1cee912bcea5de53227'), ObjectId('684ba1cee912bcea5de53228'), ObjectId('684ba1cee912bcea5de53229'), ObjectId('684ba1cee912bcea5de5
# ...

# %%
# 네이버 오픈 API + 엑셀 저장
import requests
from openpyxl import Workbook, load_workbook
import re

wb = Workbook()

# 첫번째 sheet 가져오기
ws = wb.active

# 시트명 변경
ws.title = "네이버쇼핑"

# 제목행 추가
ws.append(["순위", "상품명", "가격", "주소"])

# 셀 너비 조절
ws.column_dimensions["B"].width = 100
ws.column_dimensions["D"].width = 80

url = "https://openapi.naver.com/v1/search/shop.json"
headers = {
    "X-Naver-Client-Id": "YLPcyRzSCyVPhrp4HzrV",
    "X-Naver-Client-Secret": "We7CJm5vgN",
}

start = 1
book_csv_list = []
no = 1

for idx in range(10):
    start_num = start + (idx * 100)

    params = {"query": "마우스", "display": 100, "start": start_num}

    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(contents)

    for item in contents["items"]:
        # title 의 <b> 태그 제거
        title = re.sub("<.*?>", "", item["title"])
        print(no, title, item["lprice"], item["link"])

        ws.append([no, title, item["lprice"], item["link"]])
        no += 1

# 엑셀파일 저장
wb.save("./data/sample1.xlsx")
wb.close()
# Out:
# 1 로지텍 무선마우스 G304 LIGHTSPEED 무선 게이밍마우스 롤 배그 블랙 병행 42000 https://smartstore.naver.com/main/products/4882707794
# 2 VXE R1 SE+ 19900 https://search.shopping.naver.com/catalog/55130347282
# 3 로지텍 로지텍G PRO X SUPERLIGHT 2 게이밍 마우스 블랙 185000 https://search.shopping.naver.com/catalog/52649143883
# 4 로지텍G G304 LIGHTSPEED 게이밍 마우스 블랙 35960 https://search.shopping.naver.com/catalog/52649215257
# 5 로지텍 MX MASTER 3S 그래파이트 138990 https://search.shopping.naver.com/catalog/52648750882
# 6 로지텍 MX Anywhere 3S 그래파이트 94500 https://search.shopping.naver.com/catalog/52649430184
# 7 지클릭커 르캄프2 초경량 듀얼 8K 게이밍 마우스 OP200 화이트 69640 https://search.shopping.naver.com/catalog/53686328148
# 8 지클릭커 쓸떼많은 다쿠아즈 무소음 무선 블루투스 마우스 화이트 14900 https://search.shopping.naver.com/catalog/52649590934
# 9 지클릭커 버티컬 도톰쉬폰 무소음 인체공학 블루투스 무선 마우스 OP50 그린 24800 https://search.shopping.naver.com/catalog/52798284940
# 10 로지텍 M331 무소음 블랙 24200 https://search.shopping.naver.com/catalog/52649066849
# ...
